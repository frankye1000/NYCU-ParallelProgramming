# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

# %%
# iter
x1   = ['1000','10000','100000']
 
# speedup
y1 = [6.83,34.416,321.115]
y2 = [9.425,37.152,323.942]
y3 = [10.399,46.646,406.263]
 
# 设置画布大小
plt.figure(figsize=(8, 4))
 
# 标题
plt.title("view1")
 
# 数据
plt.plot(x1, y1, label='method1', linewidth=3, color='r', marker='o', markerfacecolor='gray', markersize=6,linestyle="--")
plt.plot(x1, y2, label='method2', linewidth=3, color='g', marker='o', markerfacecolor='gray', markersize=6,linestyle="--")
plt.plot(x1, y3, label='method3', linewidth=3, color='b', marker='o', markerfacecolor='gray', markersize=6,linestyle="--")
 
# 横坐标描述
plt.xlabel('iter')
 
# 纵坐标描述
plt.ylabel('thread exe time')
  
plt.legend()
plt.show()

# %%
# iter
x1   = ['1000','10000','100000']
 
# speedup
y1 = [3.839, 7.056, 32.764]
y2 = [6.488, 9.757, 34.915]
y3 = [7.087, 17.709, 108.48]
 
# 设置画布大小
plt.figure(figsize=(8, 4))
 
# 标题
plt.title("view2")
 
# 数据
plt.plot(x1, y1, label='method1', linewidth=3, color='r', marker='o', markerfacecolor='gray', markersize=6, linestyle="--")
plt.plot(x1, y2, label='method2', linewidth=3, color='g', marker='o', markerfacecolor='gray', markersize=6, linestyle="--")
plt.plot(x1, y3, label='method3', linewidth=3, color='b', marker='o', markerfacecolor='gray', markersize=6, linestyle="--")
 
# 横坐标描述
plt.xlabel('iter')
 
# 纵坐标描述
plt.ylabel('thread exe time')
 
 
plt.legend()
plt.show()
